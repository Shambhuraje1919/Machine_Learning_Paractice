# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhuraje1919/Machine_Learning_Paractice/blob/main/AI_Vs_Student_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("laveshjadon/ai-impact-on-students")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'ai-impact-on-students' dataset.
# Path to dataset files: /kaggle/input/ai-impact-on-students

# %%
import pandas as pd

# %%
dp = pd.read_csv("/content/ai_student_impact_dataset (1).csv")

# %%
dp.describe()
# Out:
#           Student_ID  Pre_Semester_GPA  Weekly_GenAI_Hours  Tool_Diversity  \
# count   50000.000000      50000.000000        50000.000000     50000.00000
# mean   125000.500000          3.146102            8.427752         2.80026
# std     14433.901067          0.478854            8.269490         1.18802
# min    100001.000000          1.183000            0.000000         1.00000
# 25%    112500.750000          2.834000            2.390000         2.00000
# 50%    125000.500000          3.210000            5.800000         3.00000
# 75%    137500.250000          3.521000           11.720000         4.00000
# max    150000.000000          3.998000           40.000000         5.00000
#
#        Traditional_Study_Hours  Perceived_AI_Dependency  \
# count             50000.000000             50000.000000
# mean                 11.209271                 3.505360
# std                   5.156426                 1.820812
# min                   1.000000                 1.000000
# ...

# %%
dp.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
dp["Skill_Retention_Score"].min()
#dp["Burnout_Risk_Level"].min()
# Out:
# 10.78

# %%
print(dp.all())
# Out:
# Student_ID                     True
# Major_Category                 True
# Year_of_Study                  True
# Pre_Semester_GPA               True
# Weekly_GenAI_Hours            False
# Primary_Use_Case               True
# Prompt_Engineering_Skill       True
# Tool_Diversity                 True
# Paid_Subscription             False
# Traditional_Study_Hours        True
# Perceived_AI_Dependency        True
# Institutional_Policy           True
# Anxiety_Level_During_Exams     True
# Post_Semester_GPA              True
# Skill_Retention_Score          True
# Burnout_Risk_Level             True
# dtype: bool

# %%
dp['Post_Semester_GPA'].mean()
# Out:
# np.float64(3.34929942)

# %%
dp.columns
dp.drop_duplicates()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
dp.shape
dp.size
dp.index
dp.dtypes
# Out:
# Student_ID                      int64
# Major_Category                 object
# Year_of_Study                  object
# Pre_Semester_GPA              float64
# Weekly_GenAI_Hours            float64
# Primary_Use_Case               object
# Prompt_Engineering_Skill       object
# Tool_Diversity                  int64
# Paid_Subscription                bool
# Traditional_Study_Hours       float64
# Perceived_AI_Dependency         int64
# Institutional_Policy           object
# Anxiety_Level_During_Exams      int64
# Post_Semester_GPA             float64
# Skill_Retention_Score         float64
# Burnout_Risk_Level             object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.plot(dp['Skill_Retention_Score'])

# %%
plt.scatter(dp['Post_Semester_GPA'],dp['Pre_Semester_GPA'])

# %%
plt.bar(dp['Skill_Retention_Score'],dp['Perceived_AI_Dependency'])
plt.xlabel("Perceived_AI_Dependency")
plt.ylabel("Skill_Retention_Score")
plt.title("Data")
# Out:
# Text(0.5, 1.0, 'Data')

# %%
sb.boxplot(dp['Burnout_Risk_Level'])
# Out:
# <Axes: ylabel='Burnout_Risk_Level'>

# %%
sb.catplot(dp['Year_of_Study'])

# %%
sb.distplot(dp['Skill_Retention_Score'],hist=False)
# Out:
# /tmp/ipykernel_11984/410527795.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dp['Skill_Retention_Score'],hist=False)
# <Axes: xlabel='Skill_Retention_Score', ylabel='Density'>

# %%
sb.lineplot(dp['Perceived_AI_Dependency'])
# Out:
# <Axes: ylabel='Perceived_AI_Dependency'>

# %%
sb.histplot(dp['Institutional_Policy'])
# Out:
# <Axes: xlabel='Institutional_Policy', ylabel='Count'>

# %%
sb.scatterplot(data=dp,x = dp['Pre_Semester_GPA'],y=dp['Post_Semester_GPA'],size=dp['Perceived_AI_Dependency'],hue=dp['Prompt_Engineering_Skill'])
# Out:
# <Axes: xlabel='Pre_Semester_GPA', ylabel='Post_Semester_GPA'>

# %%
# !pip install ydata_profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport
report = ProfileReport(dp, minimal = True,title = "Project Data")
report.to_file("report.html")
report.to_notebook_iframe()
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-05-16 07:11:54.127158&quot; name=date&gt;&lt;title&gt;Project Data&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
