# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhuraje1919/Machine_Learning_Paractice/blob/main/Student_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
shambhurajejagadale_student_performance_prediction_dataset_path = kagglehub.dataset_download('shambhurajejagadale/student-performance-prediction-dataset')

print('Data source import complete.')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/kaggle/input/datasets/shambhurajejagadale/student-performance-prediction-dataset/student_dataset_10000_rows.csv")

# Show first 5 rows
print(df.head())

# Dataset information
print("\nDataset Info:")
print(df.info())

# Statistical summary
print("\nSummary Statistics:")
print(df.describe())

# Exam score distribution
df["exam_score"].hist()

plt.title("Exam Score Distribution")
plt.xlabel("Exam Score")
plt.ylabel("Number of Students")

plt.show()

# Placement status count
print("\nPlacement Status Counts:")
print(df["placement_status"].value_counts())

# %%
import matplotlib.pyplot as plt

# Exam score histogram
df["exam_score"].hist()

plt.title("Exam Score Distribution")
plt.xlabel("Exam Score")
plt.ylabel("Count")

plt.show()

# %%
from ydata_profiling import ProfileReport
from IPython.display import IFrame

profile = ProfileReport(df, minimal=True)

profile.to_file("report.html")

IFrame(src="report.html", width=1000, height=600)

# %% [markdown]
# ****Y_data Profiling****
