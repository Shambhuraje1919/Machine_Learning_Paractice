# %% [markdown]
# Pandas Practice

# %%
import pandas as pd

# %%
data = pd.DataFrame({
    "name":["Rahul", "Messi", "shambhu","king","sony"],
    "Marks":[90,86,95,99,99]
})
print(type(data))
data = data.sort_values(by="Marks",ascending=False)
data = data.reset_index(drop=True)
data = data.head(5)
data = data.rename(columns={"name":"Student Name","Marks":"Student Marks"})
#data = data.style.set_caption("Top 3 Students")
print(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   Student Name  Student Marks
# 0         sony             99
# 1         king             99
# 2      shambhu             95
# 3        Rahul             90
# 4        Messi             86
