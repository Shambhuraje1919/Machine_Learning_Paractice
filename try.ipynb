# %%
print("hiii")
# Out:
# hiii

# %%
print(1+1) ,print(1+1)
# Out:
# 2
# 2
# (None, None)

# %% [markdown]
# hiii

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import sqrt,pi
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import numpy as np ## np is alias

# %%
from math import *
print(sqrt(500))
print(pi)
# Out:
# 22.360679774997898
# 3.141592653589793

# %%
from package  import maths
print(11,111)
# Out:
# 11 111

# %%
to_do_list = ["Need to buy groceries","clean the house", "Pay Bills"]

## adding new rask
to_do_list.append("Scedual a meeting")
to_do_list.append("Go For a Run")

## Removing a Completed Task
to_do_list.remove("clean the house")

## checking if a task is in list
if "Pay Bills"  in to_do_list:
    print("you have to pay bills")

print(to_do_list)
# Out:
# you have to pay bills
# ['Need to buy groceries', 'Pay Bills', 'Scedual a meeting', 'Go For a Run']

# %% [markdown]
# Fuction is A Block Of Code Performnce A Specific Task:-

# %%
def even_or_odd(num):
    if num%2 ==0:
        return "Even"
    else:
        return "odd"

# %%
## calling the function
even_or_odd(0)
# Out:
# 'Even'

# %%
def add(a,b):
    print("This will never be printed")   
    return a+b
     
result = add(2,6)
print(result)
# Out:
# This will never be printed
# 8

# %%
def greet(name= "User"):
    print(f"Hello Sir/Mam {name},How are You")

greet("sam")
# Out:
# Hello Sir/Mam sam,How are You

# %%
### Variable Length Arguments
def numbers(*args):
    for numbers in args:
        print(numbers)

# %%
numbers(1,2,3,4,4,5,6,7,8,8,8,)
# Out:
# 1
# 2
# 3
# 4
# 4
# 5
# 6
# 7
# 8
# 8
# 8

# %%
def multiplie(a,b):
    return a*b

multiplie(4,5)

# %%
def multiplie(a,b):
    return a*b,a,a,b

multiplie(4,5) ## multiple para
multiplie(4,5) ## multiple para
# Out:
# (20, 4, 4, 5)
