# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhuraje1919/Machine_Learning_Paractice/blob/main/langchain_api_calling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
api_key = '*******************************'

# %%
llm = ChatGoogleGenerativeAI(
    model = "gemini-3.5-flash",
    temperature=0.7,
    google_api_key = api_key,
    max_retries=5
)

# %%
prompt = 'give me a good roadmap of langchain learning'
response = llm.invoke(prompt)
print('suggestions', response)
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# /tmp/ipykernel_1643/2524965636.py in <cell line: 0>()
#       1 prompt = 'give me a good roadmap of langchain learning'
# ----> 2 response = llm.invoke(prompt)
#       3 print('suggestions', response)
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in invoke(self, input, config, code_execution, stop, **kwargs)
#    2789                 raise ValueError(msg)
#    2790
# -> 2791         return super().invoke(input, config, stop=stop, **kwargs)
#    2792
#    2793     def _get_ls_params(
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     474             cast(
#     475                 "ChatGeneration",
# --> 476                 self.generate_prompt(
#     477                     [self._convert_input(input)],
# ...

# %%
# !pip install langchain_groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.4 MB/s eta 0:00:00
# ...

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key= api_key
)

# %%
prompt = 'give me a good roadmap of langchain learning'
response = llm.invoke(prompt)
print('suggestions', response)
# Out:
# suggestions content="LangChain is a powerful framework for building applications that interact with large language models (LLMs). Here's a suggested roadmap for learning LangChain:\n\n**Phase 1: Fundamentals (1-2 weeks)**\n\n1. **Introduction to LangChain**:\n\t* Read the official LangChain documentation and tutorials.\n\t* Understand the core concepts, such as agents, tools, and memories.\n2. **Large Language Models (LLMs)**:\n\t* Learn the basics of LLMs, including their architecture, training, and applications.\n\t* Familiarize yourself with popular LLMs, such as transformer-based models (e.g., BERT, RoBERTa).\n3. **Python and Programming**:\n\t* Ensure you have a solid grasp of Python programming fundamentals (e.g., data structures, control structures, functions).\n\t* Learn about popular Python libraries, such as `transformers` and `torch`, which are commonly used with LangChain.\n\n**Phase 2: LangChain Core Concepts (2-4 weeks)**\n\n1. **Agents**:\n\t* Learn about the different
# ...

# %%
response = llm.invoke("Give me a roadmap to learn LangChain.")
print(response.content)
# Out:
# LangChain is a powerful framework for building applications that utilize large language models (LLMs). Here's a roadmap to help you learn LangChain:
#
# **Prerequisites**
#
# 1. Familiarity with Python programming language
# 2. Basic understanding of natural language processing (NLP) concepts
# 3. Experience with large language models (LLMs) or transformer-based architectures
#
# **Step 1: Learn the Basics of LangChain (1-2 weeks)**
#
# 1. Start with the official LangChain documentation: <https://langchain.readthedocs.io/>
# 2. Read the introduction, installation, and getting started sections
# 3. Understand the core concepts: Agents, Indexes, Chains, and Embeddings
# 4. Familiarize yourself with the LangChain API and its components
#
# **Step 2: Understand the Architecture and Components (2-4 weeks)**
#
# 1. Study the LangChain architecture and its components:
# 	* Agents: Learn how to create and manage agents, which are the core units of computation in LangChain
# ...

# %%
response = llm.invoke("Give me info about Shambhuraje Jagadale from barshi")
print(response)
# Out:
# content="I couldn't find any specific information on a person named Shambhuraje Jagadale from Barshi. It's possible that the person is a private individual or not a public figure, or the name might be misspelled or not well-known.\n\nHowever, I can suggest some alternatives to help you find more information:\n\n1. **Local sources**: You can try searching local newspapers, magazines, or online forums related to Barshi or the surrounding region to see if there are any mentions of Shambhuraje Jagadale.\n2. **Social media**: You can try searching social media platforms like Facebook, Twitter, or LinkedIn to see if Shambhuraje Jagadale has a profile or if anyone has mentioned them.\n3. **Public records**: If Shambhuraje Jagadale is a public figure or has been involved in any notable activities, you can try searching public records or databases like Wikipedia, Wikidata, or other online directories.\n4. **Local government or community websites**: You can also try searching the official webs
# ...
