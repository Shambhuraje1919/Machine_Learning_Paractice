# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhuraje1919/Machine_Learning_Paractice/blob/main/MinMax%20_Standard_Scaler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler , StandardScaler

# %%
df = pd.read_csv("/content/indian_realestate_dataset_1000.csv")
df.head()
# Out:
#   property_id       city     district      property_type  built_up_area_sqft  \
# 0   PROP00001    Chennai   Anna Nagar          Apartment                1526
# 1   PROP00002     Mumbai       Bandra             Studio                 424
# 2   PROP00003    Chennai   Anna Nagar          Apartment                1333
# 3   PROP00004       Pune  Viman Nagar  Independent House                4121
# 4   PROP00005  Bangalore  Indiranagar              Villa                4020
#
#    price_inr  price_per_sqft_inr  bedrooms  bathrooms  age_years  ...  \
# 0   10000000                6553         2          1          4  ...
# 1   50000000              117924         1          1          6  ...
# 2   10000000                7501         3          1         27  ...
# 3   15000000                3639         3          2         26  ...
# 4   30000000                7462         5          3         28  ...
#
#   annual_rental_yield_pct price_category  estimated_roi_5yr_pct  listing_date  \
# ...

# %%
print("original data")
df.head()
# Out:
# original data
#   property_id       city     district      property_type  built_up_area_sqft  \
# 0   PROP00001    Chennai   Anna Nagar          Apartment                1526
# 1   PROP00002     Mumbai       Bandra             Studio                 424
# 2   PROP00003    Chennai   Anna Nagar          Apartment                1333
# 3   PROP00004       Pune  Viman Nagar  Independent House                4121
# 4   PROP00005  Bangalore  Indiranagar              Villa                4020
#
#    price_inr  price_per_sqft_inr  bedrooms  bathrooms  age_years  ...  \
# 0   10000000                6553         2          1          4  ...
# 1   50000000              117924         1          1          6  ...
# 2   10000000                7501         3          1         27  ...
# 3   15000000                3639         3          2         26  ...
# 4   30000000                7462         5          3         28  ...
#
# ...

# %%
area_scaler = MinMaxScaler()
price_Scaler = StandardScaler()
print(df.columns.to_list())
# Out:
# ['property_id', 'city', 'district', 'property_type', 'built_up_area_sqft', 'price_inr', 'price_per_sqft_inr', 'bedrooms', 'bathrooms', 'age_years', 'facing', 'amenities', 'amenities_count', 'walkability_score', 'monthly_rental_estimate_inr', 'annual_rental_yield_pct', 'price_category', 'estimated_roi_5yr_pct', 'listing_date', 'days_on_market', 'status', 'registration_days', 'is_gated_community', 'has_maintenance_fee', 'monthly_maintenance_inr']

# %%
df["built_up_area_sqft"] = MinMaxScaler().fit_transform(df[["built_up_area_sqft"]])
df["price_inr"] = StandardScaler().fit_transform(df[["price_inr"]])

# %%
df.head()
# Out:
#   property_id       city     district      property_type  built_up_area_sqft  \
# 0   PROP00001    Chennai   Anna Nagar          Apartment            0.130734
# 1   PROP00002     Mumbai       Bandra             Studio            0.017650
# 2   PROP00003    Chennai   Anna Nagar          Apartment            0.110929
# 3   PROP00004       Pune  Viman Nagar  Independent House            0.397024
# 4   PROP00005  Bangalore  Indiranagar              Villa            0.386660
#
#    price_inr  price_per_sqft_inr  bedrooms  bathrooms  age_years  ...  \
# 0  -1.078295                6553         2          1          4  ...
# 1   1.622569              117924         1          1          6  ...
# 2  -1.078295                7501         3          1         27  ...
# 3  -0.740687                3639         3          2         26  ...
# 4   0.272137                7462         5          3         28  ...
#
#   annual_rental_yield_pct price_category  estimated_roi_5yr_pct  listing_date  \
# ...
