# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhuraje1919/Machine_Learning_Paractice/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("brendan45774/test-file")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 11.2k/11.2k [00:00<00:00, 15.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/brendan45774/test-file/versions/6

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import  RandomForestClassifier
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
os.listdir(path)
# Out:
# ['tested.csv']

# %%
df = pd.read_csv(os.path.join(path,"tested.csv"))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df["Age"]= df["Age"].fillna(df["Age"].mean())

# %%
df["Fare"]= df["Fare"].fillna(df["Fare"].mean())

# %%
df.isnull().sum()

# %%
df = df.drop("Cabin",axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Name      418 non-null    object
#  3   Sex       418 non-null    object
#  4   Age       418 non-null    float64
#  5   Ticket    418 non-null    object
#  6   Fare      418 non-null    float64
#  7   Embarked  418 non-null    object
#  8   family    418 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 29.5+ KB

# %%
df = df.drop("PassengerId",axis=1)

# %%
df["family"] = df["SibSp"]+df["Parch"]

# %%
df = df.drop(columns =["SibSp","Parch",], axis =1)

# %%
df = df.drop(columns =["Name"], axis =1)

# %%
df.head(10)
# Out:
#    Survived  Pclass   Age     Ticket     Fare  family  Sex_male  Embarked_Q  \
# 0         0       3  34.5     330911   7.8292       0      True        True
# 1         1       3  47.0     363272   7.0000       1     False       False
# 2         0       2  62.0     240276   9.6875       0      True        True
# 3         0       3  27.0     315154   8.6625       0      True       False
# 4         1       3  22.0    3101298  12.2875       2     False       False
# 5         0       3  14.0       7538   9.2250       0      True       False
# 6         1       3  30.0     330972   7.6292       0     False        True
# 7         0       2  26.0     248738  29.0000       2      True       False
# 8         1       3  18.0       2657   7.2292       0     False       False
# 9         0       3  21.0  A/4 48871  24.1500       2      True       False
#
#    Embarked_S
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
# 5        True
# 6       False
# ...

# %%
df = pd.get_dummies(df,columns=["Sex","Embarked"],drop_first=True)

# %%
df = df.drop("Ticket",axis=1)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'Fare', 'family', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    418 non-null    int64
#  1   Pclass      418 non-null    int64
#  2   Age         418 non-null    float64
#  3   Fare        418 non-null    float64
#  4   family      418 non-null    int64
#  5   Sex_male    418 non-null    bool
#  6   Embarked_Q  418 non-null    bool
#  7   Embarked_S  418 non-null    bool
# dtypes: bool(3), float64(2), int64(3)
# memory usage: 17.7 KB

# %%
x = df.drop("Survived",axis =1)
y = df["Survived"]

# %%
for i in [1, 10, 42, 100]:
    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.2, random_state=i
    )

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred = model.predict(x_test)

# %%
print(accuracy_score(pred,y_test))
# Out:
# 1.0

# %%
print(confusion_matrix(pred, y_test))
# Out:
# [[52  0]
#  [ 0 32]]

# %%
print(x.columns)
# Out:
# Index(['Pclass', 'Age', 'Fare', 'family', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
print("Got 100 percent accuracy its overfitting BTW   (:")
# Out:
# Got 100 percent accuracy its overfitting BTW   (:
