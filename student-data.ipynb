# %% [markdown]
# <a href="https://www.kaggle.com/code/shambhurajejagadale/student-data?scriptVersionId=327160028" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/kaggle/input/datasets/shambhurajejagadale/student-performance-prediction-dataset/student_dataset_10000_rows.csv")

# Show first 5 rows
print(df.head())

# Dataset information
print("\nDataset Info:")
print(df.info())

# Statistical summary
print("\nSummary Statistics:")
print(df.describe())

# Exam score distribution
df["exam_score"].hist()

plt.title("Exam Score Distribution")
plt.xlabel("Exam Score")
plt.ylabel("Number of Students")

plt.show()

# Placement status count
print("\nPlacement Status Counts:")
print(df["placement_status"].value_counts())
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ...

# %%
import matplotlib.pyplot as plt

# Exam score histogram
df["exam_score"].hist()

plt.title("Exam Score Distribution")
plt.xlabel("Exam Score")
plt.ylabel("Count")

plt.show()

# %%
from ydata_profiling import ProfileReport
from IPython.display import IFrame

profile = ProfileReport(df, minimal=True)

profile.to_file("report.html")

IFrame(src="report.html", width=1000, height=600)
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
#         <iframe
#             width="1000"
#             height="600"
#             src="report.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ****Y_data Profiling****
