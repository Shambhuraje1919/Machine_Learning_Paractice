# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhuraje1919/Machine_Learning_Paractice/blob/main/fraud_dectection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("velvetcrystal/telecom-fraud-detection-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'telecom-fraud-detection-dataset' dataset.
# Path to dataset files: /kaggle/input/telecom-fraud-detection-dataset

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics  import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
path
# Out:
# '/kaggle/input/telecom-fraud-detection-dataset'

# %%
os.listdir(path)
# Out:
# ['telecom_fraud_detection_dataset.csv']

# %%
df = pd.read_csv(os.path.join(path,'telecom_fraud_detection_dataset.csv'))

# %%
df.head()
# Out:
#        call_id  caller_age_days  calls_per_day  call_duration_sec  \
# 0  CALL0000001              735              7                449
# 1  CALL0000002               63              4                 29
# 2  CALL0000003              473             24                 61
# 3  CALL0000004               91           1270                 27
# 4  CALL0000005               14           1344                 69
#
#    avg_call_duration_sec  unique_receivers_24h  receiver_block_rate  \
# 0                  372.5                     9                12.60
# 1                   26.3                     8                52.01
# 2                   72.8                     6                 5.24
# 3                   37.1                   156                36.88
# 4                   64.8                   135                72.19
#
#    spam_reports_count  country_code_risk_score  night_call_ratio  \
# 0                   4                    26.08             15.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   call_id                      10000 non-null  object
#  1   caller_age_days              10000 non-null  int64
#  2   calls_per_day                10000 non-null  int64
#  3   call_duration_sec            10000 non-null  int64
#  4   avg_call_duration_sec        10000 non-null  float64
#  5   unique_receivers_24h         10000 non-null  int64
#  6   receiver_block_rate          10000 non-null  float64
#  7   spam_reports_count           10000 non-null  int64
#  8   country_code_risk_score      10000 non-null  float64
#  9   night_call_ratio             10000 non-null  float64
#  10  sequential_dialing_score     10000 non-null  float64
#  11  graph_degree                 10000 non-null  int64
#  12  previous_fraud_associations  10000 non-null  int64
# ...

# %%
df = df.drop("call_id",axis=1)

# %%
df.describe()
# Out:
#        caller_age_days  calls_per_day  call_duration_sec  \
# count     10000.000000    10000.00000       10000.000000
# mean        773.626600      237.47800         213.367100
# std         728.549185      406.43526         163.899768
# min           0.000000        1.00000           1.000000
# 25%         244.000000        6.00000          62.000000
# 50%         618.000000       13.00000         198.000000
# 75%        1088.000000      317.25000         314.000000
# max        3650.000000     1500.00000        1170.000000
#
#        avg_call_duration_sec  unique_receivers_24h  receiver_block_rate  \
# count           10000.000000          10000.000000         10000.000000
# mean              210.615840             50.356400            25.088838
# std               177.032595             77.776385            26.525415
# min                 1.000000              0.000000             0.090000
# 25%                55.800000              7.000000             5.960000
# ...

# %%
df.isnull().mean()*100
# Out:
# caller_age_days                0.0
# calls_per_day                  0.0
# call_duration_sec              0.0
# avg_call_duration_sec          0.0
# unique_receivers_24h           0.0
# receiver_block_rate            0.0
# spam_reports_count             0.0
# country_code_risk_score        0.0
# night_call_ratio               0.0
# sequential_dialing_score       0.0
# graph_degree                   0.0
# previous_fraud_associations    0.0
# reputation_score               0.0
# fraud_label                    0.0
# dtype: float64

# %%
df['fraud_label'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# Name: fraud_label, dtype: int64

# %%
si = SimpleImputer(strategy='mean')

# %%
x = df.drop('fraud_label',axis =1)

# %%
y = df['fraud_label']

# %%
x_train , x_test , y_train ,y_test = train_test_split(x,y,train_size=0.2,random_state=44)

# %%
x_train = si.fit_transform(x_train)

# %%
x_test = si.transform(x_test)

# %%
model = LogisticRegression()

# %%
model2 = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
Y_pred = model.predict(x_test)

# %%
print((Y_pred,y_test))
# Out:
# 23.577033886072734

# %%
print(mean_absolute_percentage_error(Y_pred,y_test))
# Out:
# 1.1450066047080312

# %%
Y_pred = model.predict(x_test)

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 215696  140181.0  1.897237 -1.045324 -0.723901  0.482332 -0.682545  0.471377
# 178821  123796.0 -0.089165  0.807445 -0.169992 -0.959017  1.048850 -0.200202
# 116146   74162.0 -0.548008  1.090936  1.250841  0.059566  0.483167  0.167768
# 217497  140911.0  1.879869 -0.738779  0.074290  0.500984 -1.230859 -0.432876
# 64508    51173.0 -1.667069 -4.752934  0.176662  2.741291 -2.577133  1.085889
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 215696 -0.929156  0.182623 -0.236088  ...  0.050125  0.537400  0.001142
# 178821  0.876518 -0.042459 -0.201535  ... -0.263317 -0.629031 -0.018891
# 116146  0.545673  0.082322 -0.418184  ... -0.221859 -0.547656 -0.110065
# 217497 -0.938795  0.124620  1.580257  ...  0.060444  0.175369  0.301154
# 64508   0.988047 -0.031683  1.031368  ...  0.745247 -0.538085 -1.290726
#
# ...

# %%
df.isnull().mean()*100

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
print(model.predict_proba(x_test))
# Out:
# [[1.00000000e+00 9.28389391e-14]
#  [2.79754140e-07 9.99999720e-01]
#  [4.44089210e-16 1.00000000e+00]
#  ...
#  [1.79769089e-10 1.00000000e+00]
#  [9.99999996e-01 4.03639405e-09]
#  [1.00000000e+00 7.42343223e-16]]

# %%
model2.fit(x_test,y_test)
# Out:
# RandomForestClassifier()

# %%
y_pred2 = model.predict(x_test)

# %%
print(model2.predict_proba(x_test))
# Out:
# [[1.   0.  ]
#  [0.   1.  ]
#  [0.   1.  ]
#  ...
#  [0.01 0.99]
#  [1.   0.  ]
#  [1.   0.  ]]

# %%
print(accuracy_score(Y_pred,y_test))
# Out:
# 0.99875

# %%
print(accuracy_score(y_pred2,y_test))
# Out:
# 0.99875
